# %% [markdown]
# # create catalog,schema

# %%
# %sql
create catalog if not exists car_project

# %%
# %sql
create schema if not exists car_project.silver

# %%
# %sql
create schema if not exists car_project.gold
