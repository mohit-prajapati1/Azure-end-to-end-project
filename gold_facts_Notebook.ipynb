# %% [markdown]
# ## Creae Fact Table

# %% [markdown]
# ** Reading silver Data**

# %%
df_silver= spark.sql('''
select * from parquet.`abfss://silver-layer@adlcarproject.dfs.core.windows.net/carsalesdata`''')

df_silver.display()
